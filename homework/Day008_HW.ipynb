# %% [markdown]
# # 靜態網頁的資料爬蟲策略
#
#
# * 了解靜態網頁的資料爬蟲策略
# * 認識適用於靜態網頁爬蟲的相關套件工具：Request
# * 認識適用於靜態網頁爬蟲的相關套件工具：BeatifulSoup

# %% [markdown]
# ## 作業目標
#
# 利用 Request + BeatifulSoup 爬取下列兩個網站內容並解析：
#
# 1. Dcared 網址： https://www.dcard.tw/f
# 2. 知乎： https://www.zhihu.com/explore
#
# 並且回答下面問題：
#
# 1. Request 取回之後該怎麼取出資料，資料型態是什麼？
# 2. 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？
# 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %% [markdown]
# ### 1. Dcard 網址： https://www.dcard.tw/f

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.dcard.tw/f'

r = requests.get(url)

r.encoding = 'utf-8'
print(r.text)
# Out:
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><link rel="stylesheet" type="text/css" href="https://fonts.googleapis.com/css?family=Roboto:400,300"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png"/><link rel="apple-touch-icon" type="image/png" sizes="72x72" href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png"/><link rel="apple-touch-icon" type="image/png" sizes="76x76" href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png"/><link rel="apple-touch-icon" type="image/png" sizes="114x114" href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png"/><link rel="apple-touch-icon" type="image/png" sizes="120x120" href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png"/><link rel="apple-touch-icon" type="image/png" sizes="144x144" href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png"/><link rel="apple-touch-icon" type="image/png" sizes="152x152" href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png"/><link rel="apple-touch-icon" type="image/png" sizes="180x180" href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png"/><link rel="shortcut icon" type="image/png" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-TWLTW4M');</script><meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1"/><meta charSet="utf-8"/><meta name="description" content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"/><meta property="og:description" content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"/><meta property="og:type" content="website"/><meta property="twitter:description" content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"/><meta name="image" itemProp="image" content="https://www.dcard.tw/images/landing.png"/><meta property="og:image" content="https://www.dcard.tw/images/landing.png"/><meta property="og:image:secure_url" content="https://www.dcard.tw/images/landing.png"/><meta property="twitter:image" content="https://www.dcard.tw/images/landing.png"/><title>Dcard</title><link rel="canonical" href="https://www.dcard.tw/f"/><meta name="url" itemProp="url" content="https://www.dcard.tw/f"/><meta property="og:site_name" content="Dcard"/><meta property="og:title" content="Dcard"/><meta property="og:url" content="https://www.dcard.tw/f"/><meta property="twitter:title" content="Dcard"/><meta property="al:android:url" content="dcard://category/all/%E5%85%A8%E9%83%A8/hot"/><meta property="al:ios:url" content="dcard://category"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"CollectionPage","name":"Dcard","url":"https://www.dcard.tw/f","description":"廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"}</script><script type="application/ld+json">{"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Dcard","item":"https://www.dcard.tw"},{"@type":"ListItem","position":2,"name":"全部","item":"https://www.dcard.tw/f"}]}</script><meta name="next-head-count" content="21"/><link rel="preload" href="/_next/static/css/6d1bbc10820647a103b8.css" as="style"/><link rel="stylesheet" href="/_next/static/css/6d1bbc10820647a103b8.css"/><link rel="preload" href="/_next/static/qeULUZnaE40GZuX19ZeEu/pages/forum.js" as="script"/><link rel="preload" href="/_next/static/qeULUZnaE40GZuX19ZeEu/pages/_app.js" as="script"/><link rel="preload" href="/_next/static/chunks/commons.a7927da712c2b615dfc7.js" as="script"/><link rel="preload" href="/_next/static/chunks/594bfe24906a2ede671370e37681d9c23b5e51d0.dbf2953254398f42164a.js" as="script"/><link rel="preload" href="/_next/static/chunks/b25bcdb1e7ba05b12936d4c250bc53fdddb47360.7693a06c8d147e1bd3c6.js" as="script"/><link rel="preload" href="/_next/static/chunks/b93030b0bbb2a681ce954d756d210dd3b22091cd.973fcdc6f3c8b3c0637e.js" as="script"/><link rel="preload" href="/_next/static/chunks/89.a5d9aa8d04c9389f37c1.js" as="script"/><link rel="preload" href="/_next/static/chunks/6ed2ac0cfb28e2327638daeda163ae54e78a01ba.7100a99d0af72d20cd4a.js" as="script"/><link rel="preload" href="/_next/static/chunks/3c4859d19f00ad0f5d804de5d236492f40221cb1.7cca386140609e544ff4.js" as="script"/><link rel="preload" href="/_next/static/chunks/100.e1b0c5c3146d96eeb1c5.js" as="script"/><link rel="preload" href="/_next/static/chunks/117.3b6ae08346082b6eeb6e.js" as="script"/><link rel="preload" href="/_next/static/chunks/df0946cb4c0865cc26c76e30ee9a63d7ed2f4911.683e2507bd25f2b774ce.js" as="script"/><link rel="preload" href="/_next/static/chunks/80d87c3548640ac7623a7f3e4a7b23b6e2843474.a14f21e81ee4ca85b5a5.js" as="script"/><link rel="preload" href="/_next/static/chunks/101.186253343ad69178d294.js" as="script"/><link rel="preload" href="/_next/static/chunks/122.36fac467ed3d00c822e2.js" as="script"/><link rel="preload" href="/_next/static/chunks/104.ace3a73d22498f4b5957.js" as="script"/><link rel="preload" href="/_next/static/chunks/462f53e82956e978ffc7b9950012c598b58e8cd4.cff47e2afb4b09e017dd.js" as="script"/><link rel="preload" href="/_next/static/chunks/fd9e4387cac53e3e01237a32ef8edb7c5ba4b868.d5dfc3ae04ba5cb3723e.js" as="script"/><link rel="preloa ...
# /* sc-component-id: sc-global-1522344194 */
# body{background-color:#00324e;}
# /* sc-component-id: ksi2hf-0 */
# .eNbBFe{display:none;}
# /* sc-component-id: ydgdj7-0 */
# .hhSnba{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .hhSnba img,.hhSnba svg{height:100%;width:100%;}.gCQlMD{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:26px;height:26px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .gCQlMD img,.gCQlMD svg{height:100%;width:100%;}.iYfIzd{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .iYfIzd img,.iYfIzd svg{height:100%;width:100%;}.jkPESf{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:40px;height:40px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .jkPESf img,.jkPESf svg{height:100%;width:100%;}.cbhXy{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .cbhXy img,.cbhXy svg{height:100%;width:100%;}.iUPhXV{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:28px;height:28px;fill:#c4c4c4;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .iUPhXV img,.iUPhXV svg{height:100%;width:100%;}.dcqUEg{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:16px;height:16px;fill:#f8b048;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .dcqUEg img,.dcqUEg svg{height:100%;width:100%;}.gRIdVl{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .gRIdVl img,.gRIdVl svg{height:100%;width:100%;}.ieFmwo{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:16px;height:16px;fill:rgba(0,0,0,.6);stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .ieFmwo img,.ieFmwo svg{height:100%;width:100%;}.joALQw{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#3397cf;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .joALQw img,.joALQw svg{height:100%;width:100%;}.iLWWtS{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:18px;height:18px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .iLWWtS img,.iLWWtS svg{height:100%;width:100%;}.bwTNRH{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:44px;height:44px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);}  ...
# /* sc-component-id: sc-1ag928-0 */
# .kUMklR{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;outline:none;font-size:16px;line-height:normal;border-radius:4px;padding:0 10px;height:40px;width:100%;-webkit-flex:1;-ms-flex:1;flex:1;color:rgba(0,0,0,.85);border:1px solid rgba(0,0,0,0.25);} .kUMklR::-webkit-input-placeholder{color:#c1c2c5;} .kUMklR::-moz-placeholder{color:#c1c2c5;} .kUMklR:-ms-input-placeholder{color:#c1c2c5;} .kUMklR::placeholder{color:#c1c2c5;}
# /* sc-component-id: pw4e6a-0 */
# .ierzKU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;} .ierzKU form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}.dODGjA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;} .dODGjA form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:rgb(238,238,238);border-radius:4px;overflow:hidden;width:100%;}
# /* sc-component-id: pw4e6a-1 */
# .fWARvU{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;font-size:14px;color:#fff;}.bkAvTt{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;font-size:16px;}
# /* sc-component-id: pw4e6a-2 */
# .jMlptb{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}
# /* sc-component-id: pw4e6a-3 */
# .elZfHj{padding-left:10px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: pw4e6a-4 */
# .copHwd{padding:0 2px;}
# /* sc-component-id: sc-1divb7s-0 */
# .kkFyqs{position:-webkit-sticky;position:sticky;top:60px;background:#fafafa;border-bottom:1px solid #dedede;padding:0 60px;z-index:10;}.jGSaFz{position:-webkit-sticky;position:sticky;top:48px;background:#fff;border-bottom:1px solid #dedede;padding:0 16px;z-index:10;}
# /* sc-component-id: sc-1divb7s-1 */
# .jgHqud{padding-top:10px;}
# /* sc-component-id: sc-1divb7s-2 */
# .fvImY{height:40px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-1divb7s-3 */
# .jqcDIF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-1divb7s-4 */
# .eOmoiY{height:100%;white-space:nowrap;} .eOmoiY:first-child{padding-left:0;} .eOmoiY a{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 20px;} .eOmoiY a::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}.kQMWIM{height:100%;white-space:nowrap;} .kQMWIM:first-child{padding-left:0;} .kQMWIM a{color:#3397cf;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 20px;} .kQMWIM a::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}.iXnhSl{height:100%;white-space:nowrap;-webkit-flex:1;-ms-flex:1;flex:1;} .iXnhSl:first-child{padding-left:0;} .iXnhSl a{color:#3397cf;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 0px;} .iXnhSl a::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}.glFNEP{height:100%;white-space:nowrap;-webkit-flex:1;-ms-flex:1;flex:1;} .glFNEP:first-child{padding-left:0;} .glFNEP a{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 0px;} .glFNEP a::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}
# /* sc-component-id: r0dumd-0 */
# .hraxjl{position:fixed;top:60px;right:25px;z-index:1000;}.eZbqml{position:fixed;bottom:33px;left:50%;right:50%;width:100vw;z-index:1000;}
# /* sc-component-id: sc-84v443-0 */
# .jAlbWa{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .jAlbWa:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .jAlbWa:hover{background:#006aa6;}.kgcVsA{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:13px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .kgcVsA:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.kGxGfT{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:1px solid #fff;color:#fff;background:transparent;} .kGxGfT:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.iIxOaU{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:none;opacity:0.5;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .iIxOaU:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .iIxOaU:hover{background:#006aa6;}.fxUbNa{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:13px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:transparent;color:rgba(0,0,0,.6);-webkit-text-decoration:underline;text-decoration:underline;} .fxUbNa:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .fxUbNa:active{box-shadow:none;}.kUHSsi{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:1px solid #c1c2c5;background:#fff;color:rgba(0,0,0,.6);} .kUHSsi:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .kUHSsi:hover{background:#efefef;} .kUHSsi:active{box-shadow:inset 0 1px 2px 0 rgba(0,0,0,0.3);}.dlKdBb{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:13px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:1px solid #fff;color:#fff;background:transparent;} .dlKdBb:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.bcPQqz{display:inline-block ...
# /* sc-component-id: sc-84v443-2 */
# .jnmJtt> button{border-radius:0;} .jnmJtt>*:first-child{border-radius:4px 0 0 4px;border-right-width:0;} .jnmJtt>*:first-child button{border-radius:4px 0 0 4px;border-right-width:0;} .jnmJtt>*:last-child{border-radius:0 4px 4px 0;border-left-width:0;} .jnmJtt>*:last-child button{border-radius:0 4px 4px 0;border-left-width:0;}
# /* sc-component-id: avchkw-0 */
# .lcIqKn{display:grid;max-width:1280px;margin:auto;padding:60px 20px 0 0;grid-template-columns:[start] 208px [mainLeft] auto [mainRight] 300px [end];-webkit-transition:grid-template-columns .5s;transition:grid-template-columns .5s;}
# /* sc-component-id: avchkw-1 */
# .dLkKRc{grid-column:start / mainLeft;}
# /* sc-component-id: avchkw-2 */
# .ciNPhh{min-width:calc(728px + 24px);grid-column:mainLeft / mainRight;}.hpsGZq{min-width:calc(undefinedpx + 0px);grid-column:mainLeft / mainRight;}
# /* sc-component-id: avchkw-3 */
# .kIHllc{grid-column:mainRight / end;}
# /* sc-component-id: sc-17vj83f-0 */
# .iJCqeQ{margin:0 12px;min-height:calc(100vh - 80px);min-width:728px;padding-top:20px;height:100%;}.kqKnyl{-webkit-flex:1;-ms-flex:1;flex:1;margin:0 0px;min-height:calc(100vh - 48px);min-width:0px;padding-top:0px;height:100%;}
# /* sc-component-id: sc-17vj83f-1 */
# .hSVvaC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-top:0px;}
# /* sc-component-id: sc-17vj83f-2 */
# .nlkop{height:100%;background:#fafafa;border-radius:4px 4px 0 0;}
# /* sc-component-id: sc-1hbn6e7-0 */
# .cAUXkt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;text-align:center;padding:50px 0;}
# /* sc-component-id: sc-1hbn6e7-1 */
# .dagORX{display:block;width:250px;margin-bottom:30px;}
# /* sc-component-id: sc-1hbn6e7-2 */
# .fIvJvb{font-size:30px;font-weight:400;line-height:42px;margin-bottom:10px;}
# /* sc-component-id: sc-1hbn6e7-3 */
# .dARMVx{color:rgba(0,0,0,.45);font-size:18px;line-height:30px;max-width:45%;}
# /* sc-component-id: cagncm-0 */
# .heuwav{position:relative;}
# /* sc-component-id: cagncm-1 */
# .LDAeQ{visibility:hidden;padding-top:calc(100% / 1.7777777777777777);pointer-events:none;}.jNwtlj{visibility:hidden;padding-top:calc(100% / 0.75);pointer-events:none;}.uMqVT{visibility:hidden;padding-top:calc(100% / 1.761111111111111);pointer-events:none;}.hEwKcb{visibility:hidden;padding-top:calc(100% / 0.5750798722044729);pointer-events:none;}.bOYByu{visibility:hidden;padding-top:calc(100% / 0.5625);pointer-events:none;}.gmOTyn{visibility:hidden;padding-top:calc(100% / 1.7843866171003717);pointer-events:none;}.bjdYUu{visibility:hidden;padding-top:calc(100% / 0.5624999999999993);pointer-events:none;}.dOkRgV{visibility:hidden;padding-top:calc(100% / 1.3333333333333333);pointer-events:none;}.euMuXn{visibility:hidden;padding-top:calc(100% / 0.45833333333333337);pointer-events:none;}.gBKTwh{visibility:hidden;padding-top:calc(100% / 1.7722222222222224);pointer-events:none;}.jVNDlw{visibility:hidden;padding-top:calc(100% / 0.5);pointer-events:none;}.jIVHRC{visibility:hidden;padding-top:calc(100% / 1);pointer-events:none;}.dcoFBG{visibility:hidden;padding-top:calc(100% / NaN);pointer-events:none;}.kzfyvZ{visibility:hidden;padding-top:calc(100% / 2.162162162162162);pointer-events:none;}.fJtwvR{visibility:hidden;padding-top:calc(100% / 0.5660377358490566);pointer-events:none;}.iOzsDO{visibility:hidden;padding-top:calc(100% / 1.775);pointer-events:none;}.kHSDfv{visibility:hidden;padding-top:calc(100% / 0.55625);pointer-events:none;}.bgyDTM{visibility:hidden;padding-top:calc(100% / 0.5203252032520326);pointer-events:none;}.iGmKuW{visibility:hidden;padding-top:calc(100% / 1.7733990147783252);pointer-events:none;}.jkGRpF{visibility:hidden;padding-top:calc(100% / 0.8);pointer-events:none;}.hZgEVT{visibility:hidden;padding-top:calc(100% / 1.7647058823529411);pointer-events:none;}.bFpKUJ{visibility:hidden;padding-top:calc(100% / 1.7857142857142856);pointer-events:none;}.ksBdyw{visibility:hidden;padding-top:calc(100% / 5);pointer-events:none;}.hgkMrI{visibility:hidden;padding-top:calc(100% / 1.0423452768729642);pointer-events:none;}.loGrpV{visibility:hidden;padding-top:calc(100% / 0.5593750000000001);pointer-events:none;}.WvYkQ{visibility:hidden;padding-top:calc(100% / 0.5678233438485805);pointer-events:none;}.bRrbVo{visibility:hidden;padding-top:calc(100% / 1.9354838709677418);pointer-events:none;}.iKKITa{visibility:hidden;padding-top:calc(100% / 1.5);pointer-events:none;}.jrzdjb{visibility:hidden;padding-top:calc(100% / 1.9047619047619047);pointer-events:none;}.pSqZd{visibility:hidden;padding-top:calc(100% / 1.4492753623188408);pointer-events:none;}.dMzLpW{visibility:hidden;padding-top:calc(100% / 1.797752808988764);pointer-events:none;}.lmWxXW{visibility:hidden;padding-top:calc(100% / 1.7679558011049723);pointer-events:none;}.hjUALt{visibility:hidden;padding-top:calc(100% / 0.46249999999999997);pointer-events:none;}.gqgmhE{visibility:hidden;padding-top:calc(100% / 0.5633802816901409);pointer-events:none;}.deRkcT{visibility:hidden;padding-top:calc(100% / 0.9574468085106382);pointer-events:none;}.ZMTGu{visibility:hidden;padding-top:calc(100% / 0.562499296875879);pointer-events:none;}.kAoXjI{visibility:hidden;padding-top:calc(100% / 1.7555555555555555);pointer-events:none;}.gSAyIA{visibility:hidden;padding-top:calc(100% / 2.1555555555555554);pointer-events:none;}.cMKEHT{visibility:hidden;padding-top:calc(100% / 0.5309734513274337);pointer-events:none;}.hVbCyk{visibility:hidden;padding-top:calc(100% / 0.73046875);pointer-events:none;}.jeIltF{visibility:hidden;padding-top:calc(100% / 0.5357142857142857);pointer-events:none;}.dNlAQx{visibility:hidden;padding-top:calc(100% / 2.1666666666666665);pointer-events:none;}.cJUXHR{visibility:hidden;padding-top:calc(100% / 0.5495283018867925);pointer-events:none;}.ejGGcN{visibility:hidden;padding-top:calc(100% / 1.787709497206704);pointer-events:none;}.ePbxdq{visibility:hidden;padding-top:calc(100% / 1.807909604519774);pointer-events:none;}.fMTeMY{visibility:hidden;padding-top:calc(100% / 1.73913043478260 ...
# /* sc-component-id: cagncm-2 */
# .fNGJuR{position:absolute;left:0;top:0;right:0;bottom:0;}
# /* sc-component-id: sc-1ist1s2-0 */
# .cRUrbl{width:100%;}
# /* sc-component-id: jo1zdl-0 */
# .rCmLK{background:#fff;box-shadow:rgba(0,0,0,0.05) 0px 4px 4px 0px,rgba(0,0,0,0.15) 0px 0px 4px 0px;position:absolute;top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);border-radius:4px;height:px;width:px;min-width:90%;max-width:calc(100vw - 48px);min-height:0;max-height:calc(100% - 48px);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;text-align:left;}.jLjFsr{background:#fff;box-shadow:rgba(0,0,0,0.05) 0px 4px 4px 0px,rgba(0,0,0,0.15) 0px 0px 4px 0px;position:absolute;top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);border-radius:4px;height:px;width:px;min-width:300px;max-width:calc(100vw - 48px);min-height:0;max-height:calc(100% - 48px);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;text-align:left;}.hzaMZS{background:#fff;box-shadow:rgba(0,0,0,0.05) 0px 4px 4px 0px,rgba(0,0,0,0.15) 0px 0px 4px 0px;position:absolute;top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);border-radius:4px;height:px;width:px;min-width:300px;max-width:calc(100vw - 48px);min-height:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;text-align:left;}
# /* sc-component-id: jo1zdl-1 */
# .dJUxnG{padding:24px 24px 10px;}.fYWvDg{padding:40px 40px 10px;}.kLyASK{padding:40px 40px 16px;}
# /* sc-component-id: jo1zdl-2 */
# .cTNmGN{position:relative;}
# /* sc-component-id: jo1zdl-3 */
# .iMYeMt{font-size:24px;font-size:20px;font-weight:700;line-height:24px;color:rgba(0,0,0,.85);text-align:left;}.bZFzBN{font-size:24px;font-weight:700;line-height:24px;color:rgba(0,0,0,.85);text-align:left;}.fOQjQ{font-size:20px;font-weight:400;line-height:24px;color:rgba(0,0,0,.85);text-align:center;}
# /* sc-component-id: jo1zdl-7 */
# .kzOwDl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-flex:1;-ms-flex:1;flex:1;overflow-y:auto;min-height:0;} .kzOwDl:nth-child(2) > div{padding-top:0;}
# /* sc-component-id: jo1zdl-8 */
# .ifDwvY{-webkit-flex:1;-ms-flex:1;flex:1;height:100%;padding:20px 24px 24px;}.dUMZtU{-webkit-flex:1;-ms-flex:1;flex:1;height:100%;padding:20px 40px 40px;}
# /* sc-component-id: sc-8dk2q5-1 */
# .iCflnd{min-height:0;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-8dk2q5-2 */
# .gpTxIH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;margin-top:20px;} .gpTxIH:first-child{margin-top:0;}
# /* sc-component-id: sc-8dk2q5-3 */
# .cuDCyD{margin-left:20px;} .cuDCyD:first-child{margin-left:0;width:100%;}.iGgriV{margin-left:20px;} .iGgriV:first-child{margin-left:0;}
# /* sc-component-id: sc-1ykc0nb-2 */
# .iNRVSl{display:inline-block;height:100%;}
# /* sc-component-id: rry249-0 */
# .eEHQqz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:32px;color:rgba(0,0,0,.6);font-size:14px;border-radius:4px;background:#efefef;padding:0 16px;white-space:nowrap;}.hXxAcg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:32px;color:rgba(0,0,0,.6);font-size:13px;border-radius:4px;background:#efefef;padding:0 16px;white-space:nowrap;}
# /* sc-component-id: sc-1285qe-0 */
# .fnbysa{overflow-y:hidden;}
# /* sc-component-id: sc-1285qe-1 */
# .frGOVM{overflow-x:auto;overflow-y:hidden;}
# /* sc-component-id: sc-1285qe-2 */
# .kwyXwr{white-space:nowrap;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:64px;padding:0 0px;} .kwyXwr::after{content:'';-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;height:64px;width:0px;}
# /* sc-component-id: sc-1285qe-3 */
# .Gmrxn{display:block;}
# /* sc-component-id: sc-1285qe-4 */
# .cRztcx{display:inline-block;padding-right:8px;padding-top:8px;} .cRztcx:last-child{padding-right:0;}.jMCMEQ{display:inline-block;padding-right:16px;padding-top:16px;} .jMCMEQ:last-child{padding-right:0;}.kixOiI{display:inline-block;padding-right:16px;padding-top:px;} .kixOiI:last-child{padding-right:0;}
# /* sc-component-id: uzae24-0 */
# .eSWhfz{width:100%;height:100%;position:relative;background:#000;}
# /* sc-component-id: uzae24-1 */
# .Fzfdz{position:absolute;top:0;left:0;width:100%;height:100%;}
# /* sc-component-id: cgkbr-0 */
# .dVbdRN{border:0;width:100%;}
# /* sc-component-id: sc-1n5ks60-0 */
# .bLpAcs{background-color:rgb(250,250,250);padding:20px 0 16px 0;border-bottom:1px solid #d9d9d9;}.ljZaZc{background-color:#fff;padding:20px 0 16px 0;border-bottom:1px solid #d9d9d9;}
# /* sc-component-id: sc-1n5ks60-1 */
# .gUkFib{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,.5);font-size:14px;margin-bottom:14px;}
# /* sc-component-id: sc-1n5ks60-2 */
# .gLEJWb{background-color:#f0b941;padding:2px 4px;border-radius:4px;color:#fff;margin-right:10px;}.gpGROt{background-color:rgba(0,0,0,0.35);padding:2px 4px;border-radius:4px;color:#fff;margin-right:10px;}
# /* sc-component-id: sc-1n5ks60-3 */
# .gsITcD{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;color:rgba(0,0,0,.5);font-size:14px;line-height:1;}
# /* sc-component-id: sc-1n5ks60-4 */
# .eEnMxW{color:#f0b941;font-weight:bold;font-size:28px;margin-right:10px;}
# /* sc-component-id: sc-1n5ks60-5 */
# .hBQCmL{-webkit-text-decoration-line:line-through;text-decoration-line:line-through;}
# /* sc-component-id: sc-1aui6l1-0 */
# .iFXkqk{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-1aui6l1-1 */
# .kyLyek{border:none;background:#a8a8a8;width:12px;height:12px;border-radius:50%;margin:0 8px;padding:0;cursor:pointer;outline:none;}.bxUwdt{border:none;background:rgba(168,168,168,0.3);width:12px;height:12px;border-radius:50%;margin:0 8px;padding:0;cursor:pointer;outline:none;}
# /* sc-component-id: sc-1v5l8ro-0 */
# .cboeuQ{position:relative;}
# /* sc-component-id: sc-1v5l8ro-2 */
# .jTdrJK{border:none;background:none;position:absolute;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);opacity:0;cursor:pointer;outline:none;padding:0;left:20px;} .sc-1v5l8ro-0:hover .jTdrJK{opacity:1;}
# /* sc-component-id: sc-1v5l8ro-3 */
# .htnUjJ{border:none;background:none;position:absolute;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);opacity:0;cursor:pointer;outline:none;padding:0;right:20px;} .sc-1v5l8ro-0:hover .htnUjJ{opacity:1;}
# /* sc-component-id: sc-1v5l8ro-5 */
# .iCmpce{position:absolute;bottom:12px;left:50%;-webkit-transform:translateX(-50%);-ms-transform:translateX(-50%);transform:translateX(-50%);}
# /* sc-component-id: sc-1xsathd-0 */
# .lbzoxB{width:100%;background-size:cover;background-position:center center;background-repeat:no-repeat;padding-bottom:75%;}
# /* sc-component-id: sc-13e2k1-0 */
# .bAfPQq{margin:20px 0;}
# /* sc-component-id: xt0n8u-0 */
# .loyxor{border:0;}
# /* sc-component-id: omlszd-0 */
# .bbxbmN{border:0;height:100%;width:100%;}
# /* sc-component-id: sc-5aa8ap-0 */
# .gpeOcj{border:0;height:100%;width:100%;}
# /* sc-component-id: sc-1r4us9h-0 */
# .gLRgot{overflow:hidden;position:relative;max-width:100%;max-height:60vh;}.cDOlbF{overflow:hidden;position:relative;max-width:100%;max-height:vh;}
# /* sc-component-id: sc-1r4us9h-1 */
# .cuCQeX{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:60vh;}.hTuwCj{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:vh;}
# /* sc-component-id: sc-1r4us9h-2 */
# .jzwjYE{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:60vh;position:absolute;top:0;left:0;}.bvlcaJ{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:vh;position:absolute;top:0;left:0;}
# /* sc-component-id: kfwtwu-0 */
# .plPAm{position:relative;height:120px;padding:16px 0;width:100%;}.jxylh{position:relative;height:64px;padding:13px 0;width:100%;}
# /* sc-component-id: w1s81u-0 */
# .ghccAs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:8px 0 6px;padding:0 10px;border:1px solid rgb(233,233,233);border-radius:4px;background:#fff;box-shadow:0 1px 2px #ddd;line-height:1.3;max-width:430px;width:100%;min-height:65px;overflow:hidden;}
# /* sc-component-id: w1s81u-1 */
# .jyJcRR{-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: w1s81u-2 */
# .cKxtrZ{margin-right:10px;border-radius:3px;overflow:hidden;background-color:#006aa6;}.dykAcs{margin-right:10px;border-radius:3px;padding:5px;overflow:hidden;background-color:#006aa6;}
# /* sc-component-id: w1s81u-3 */
# .feAVOA{-webkit-flex:1;-ms-flex:1;flex:1;min-width:0;}
# /* sc-component-id: w1s81u-4 */
# .gWtdfB{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;font-size:16px;font-weight:bold;line-height:1.3;color:rgba(0,0,0,.85);padding-bottom:5px;}
# /* sc-component-id: w1s81u-5 */
# .ogdUz{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;font-size:14px;color:rgba(0,0,0,.35);line-height:16px;height:16px;}
# /* sc-component-id: sc-1eso38c-0 */
# .lLnjb{margin:10px 0;}
# /* sc-component-id: hmo708-0 */
# .dkyZPk{white-space:pre-wrap;}
# /* sc-component-id: sc-1ro4bpk-0 */
# .jXIcFN{font-size:18px;line-height:1.6;word-wrap:break-word;}.jKdblb{font-size:15px;color:rgba(0,0,0,.6);line-height:1.6;word-wrap:break-word;}
# /* sc-component-id: sc-1ro4bpk-1 */
# .eTxtzv{padding-bottom:22px;}.bNRMtc{padding-bottom:16px;}
# /* sc-component-id: sc-1ro4bpk-2 */
# .aEXNq{padding:10px 0;border-top:1px solid rgb(233,233,233);border-bottom:1px solid rgb(233,233,233);}
# /* sc-component-id: sc-1ro4bpk-3 */
# .hPNbBN{font-size:16px;line-height:30px;color:rgba(0,0,0,.35);padding-bottom:3px;}.fMLUtJ{font-size:13px;line-height:30px;color:rgba(0,0,0,.35);padding-bottom:3px;}
# /* sc-component-id: sc-116rzs1-0 */
# .hzTqOV{font-size:30px;line-height:1.5;font-weight:500;word-wrap:break-word;color:rgba(0,0,0,.95);}.dYEYmA{font-size:19px;line-height:1.5;font-weight:500;word-wrap:break-word;color:rgba(0,0,0,.95);}
# /* sc-component-id: cra5e8-0 */
# .gpDnCL{border-radius:50%;overflow:hidden;}
# /* sc-component-id: cra5e8-1 */
# .fYHPhX{background:#cb3a6b;color:#fff;font-size:25.6px;height:40px;width:40px;line-height:40px;text-align:center;border-radius:50%;}.hbaYDn{background:#2490bf;color:#fff;font-size:25.6px;height:40px;width:40px;line-height:40px;text-align:center;border-radius:50%;}.hAyDgJ{background:#cb3a6b;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}.fPjsad{background:#2490bf;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}.iVFhUp{background:#cb3a6b;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}.buwgzc{background:#2490bf;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}.ldnNRb{background:#2490bf;color:#fff;font-size:30.72px;height:48px;width:48px;line-height:48px;text-align:center;border-radius:50%;}.ehIwJk{background:#cb3a6b;color:#fff;font-size:30.72px;height:48px;width:48px;line-height:48px;text-align:center;border-radius:50%;}.dLdNOh{background:#cb3a6b;color:#fff;font-size:64px;height:100px;width:100px;line-height:100px;text-align:center;border-radius:50%;}.eiVDLb{background:#2490bf;color:#fff;font-size:64px;height:100px;width:100px;line-height:100px;text-align:center;border-radius:50%;}
# /* sc-component-id: cra5e8-2 */
# .ksDGRc{display:block;border-radius:50%;object-fit:cover;}
# /* sc-component-id: ulutkk-0 */
# .iKgfXR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:14px;}.bdZmTC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:13px;}
# /* sc-component-id: ulutkk-1 */
# .ivbvQc{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: ulutkk-2 */
# .hXoZkZ{color:rgba(0,0,0,.6);} .hXoZkZ:not(:last-child)::after{content:'·';padding:0 0.5em;}
# /* sc-component-id: ulutkk-3 */
# .bWuoYI{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin-right:8px;}
# /* sc-component-id: ulutkk-5 */
# .eJhRoL{background-color:#a3a3a3;color:#fff;font-size:12px;padding:3px 4px;border-radius:4px;margin-left:8px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: ulutkk-6 */
# .eUUiOP{margin-left:3px;}
# /* sc-component-id: ulutkk-7 */
# .gFxUyu{-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}
# /* sc-component-id: sc-1dy4jrl-0 */
# .dGuoO{padding:16px;border:1px solid rgb(233,233,233);border-radius:4px;}
# /* sc-component-id: sc-1dy4jrl-1 */
# .hSudgn{font-size:14px;padding-bottom:8px;}
# /* sc-component-id: sc-1dy4jrl-2 */
# .qyGOB{font-size:18px;color:rgba(0,0,0,.85);font-weight:normal;padding-bottom:8px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1dy4jrl-3 */
# .cChNNo{padding:12px 0 22px;}.cHbQxZ{padding:12px 0 16px;}
# /* sc-component-id: sc-1dy4jrl-4 */
# .irssaW{font-size:14px;color:rgba(0,0,0,.6);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1dy4jrl-5 */
# .VJRLs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;color:rgba(0,0,0,.35);padding-top:50px;}
# /* sc-component-id: sc-1dy4jrl-6 */
# .kogORL:not(:last-child)::after{content:'·';padding:0 0.5em;}
# /* sc-component-id: sc-4gkg5b-0 */
# .jNSdZG{position:absolute;background:rgb(30,30,30);border-radius:4px;z-index:10;left:calc(100% + 5px + 8px);top:50%;-webkit-transform:translateY(calc(0px - 50%));-ms-transform:translateY(calc(0px - 50%));transform:translateY(calc(0px - 50%));}.kuUoxV{position:absolute;background:rgb(30,30,30);border-radius:4px;z-index:10;left:calc(100% + 5px + 8px);top:50%;-webkit-transform:translateY(calc(0px - 50%));-ms-transform:translateY(calc(0px - 50%));transform:translateY(calc(0px - 50%));width:auto;border-radius:0;}
# /* sc-component-id: sc-4gkg5b-1 */
# .hFiaOa{position:absolute;background:linear-gradient(-45deg,rgb(30,30,30) 55%,transparent 55%);height:10px;width:10px;z-index:10;left:calc(100% + 8px);top:50%;-webkit-transform:translate(0,-50%) rotateZ(135deg);-ms-transform:translate(0,-50%) rotateZ(135deg);transform:translate(0,-50%) rotateZ(135deg);}.hVlCDH{position:absolute;background:linear-gradient(-45deg,rgb(30,30,30) 55%,transparent 55%);height:10px;width:10px;z-index:10;left:calc(100% + 8px);top:50%;-webkit-transform:translate(0,-50%) rotateZ(135deg);-ms-transform:translate(0,-50%) rotateZ(135deg);transform:translate(0,-50%) rotateZ(135deg);box-shadow:none;}
# /* sc-component-id: mx40yw-0 */
# .bcJcFo{background:#fafafa;padding:0 60px 0;}.gHmUSp{background:#fff;padding:0 16px 0;}
# /* sc-component-id: mx40yw-1 */
# .buQRlc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-bottom:0px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.iGtQjR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-bottom:5px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: mx40yw-2 */
# .eJUhfX{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;}
# /* sc-component-id: mx40yw-3 */
# .hxUnBd{font-size:14px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:12px;}.XuWwf{font-size:13px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:12px;}
# /* sc-component-id: mx40yw-4 */
# .flRoDA{color:rgba(0,0,0,.35);white-space:nowrap;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;} .flRoDA:not(:last-child)::after{content:'·';padding:0 0.5em;}
# /* sc-component-id: mx40yw-5 */
# .iJnYGo{cursor:pointer;fill:#a8a8a8;} .iJnYGo:hover{fill:#595959;}
# /* sc-component-id: mx40yw-6 */
# .dTLUmr{padding:22px 0 40px;}.hldKBV{padding:16px 0 24px;}
# /* sc-component-id: mx40yw-7 */
# .kkMFCl{padding-bottom:16px;}.cMiHcM{padding-bottom:24px;}
# /* sc-component-id: sc-199taff-0 */
# .cecgEa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-left:12px;}
# /* sc-component-id: sc-199taff-1 */
# .imwAVu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,.35);font-size:14px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;} .imwAVu:hover > *{fill:#ea5c5c;}.kVAWGS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,.35);font-size:13px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}
# /* sc-component-id: sc-199taff-2 */
# .byDBmK{cursor:pointer;display:block;margin-right:14px;}.jQdHiY{cursor:pointer;display:block;margin-right:8px;}
# /* sc-component-id: sc-199taff-3 */
# .hUVsj{background:rgba(0,0,0,0.05);width:1px;height:24px;margin:0 8px 0 16px;}.gHZDSU{background:rgba(0,0,0,0.05);width:1px;height:16px;margin:0 2px 0 10px;}
# /* sc-component-id: sc-199taff-4 */
# .gYXlWv{cursor:pointer;} .gYXlWv:hover{fill:#3397cf;}
# /* sc-component-id: wpqo7k-0 */
# .kMCYaU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:16px;}.hmvoFh{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:13px;}
# /* sc-component-id: wpqo7k-1 */
# .dyRjoS{padding-right:15px;}
# /* sc-component-id: wpqo7k-2 */
# .fAWpiS{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;}
# /* sc-component-id: wpqo7k-3 */
# .eFJVVU{color:rgba(0,0,0,.85);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: wpqo7k-4 */
# .kDfHlX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;color:rgba(0,0,0,.35);padding-top:3px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: wpqo7k-5 */
# .fpNVYd{color:rgba(0,0,0,.35);}
# /* sc-component-id: wpqo7k-6 */
# .iitPqz{margin:0 0.5em;border-right:1px solid #dfdfdf;}
# /* sc-component-id: wpqo7k-7 */
# .eJGwQY{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;cursor:pointer;}
# /* sc-component-id: wpqo7k-8 */
# .jrtXBR{margin-left:3px;}
# /* sc-component-id: sc-1eyteeh-0 */
# .jEVzWj{color:rgba(0,0,0,.85);font-size:18px;padding:16px 0;border-bottom:1px solid rgb(233,233,233);position:relative;}.cuEcOa{color:rgba(0,0,0,.85);font-size:18px;padding:16px 0;border-bottom:1px solid transparent;position:relative;}.gdmrGU{color:rgba(0,0,0,.85);font-size:18px;padding:26px 20px;border-bottom:1px solid transparent;position:relative;}.bsYdqe{color:rgba(0,0,0,.85);font-size:18px;padding:26px 30px;border-bottom:1px solid transparent;position:relative;}
# /* sc-component-id: sc-1eyteeh-1 */
# .dOyvWD{margin-top:20px;padding:10px 0;border-top:1px solid rgb(233,233,233);border-bottom:1px solid rgb(233,233,233);}
# /* sc-component-id: sc-1eyteeh-2 */
# ...
# /* sc-component-id: sc-5neb7b-1 */
# .ioQcNH img{height:164px;}
# /* sc-component-id: sc-3xg43a-0 */
# .wnsDC{display:inline-block;margin:24px;color:rgba(0,0,0,.95);font-weight:500;}
# /* sc-component-id: sc-1grr821-0 */
# .klNgtq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:88px;padding:20px;background-color:#fafafa;box-shadow:0 2px 4px 0 rgba(0,0,0,0.05);margin-bottom:10px;border:1px solid rgb(222,222,222);border-radius:4px;} .klNgtq:hover{background-color:#fff;}.crrxbJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:88px;padding:16px;background-color:#fff;border-bottom:1px solid rgba(0,0,0,0.05);} .crrxbJ:hover{background-color:#fff;}
# /* sc-component-id: sc-1jgpjwr-0 */
# .jkcMEZ{height:32px;width:78px;line-height:32px;font-size:15px;font-weight:500;}.hzpNrr{height:32px;width:71px;line-height:32px;font-size:13px;font-weight:400;border-radius:32px;margin:0 16px;}
# /* sc-component-id: sc-173wqjh-1 */
# .iepwgp{padding:0 60px;}.gpdlxK{padding:0 16px;background:#fff;}
# /* sc-component-id: mfogj7-0 */
# .kufPjE{width:900px;max-width:100%;padding:20px;margin:auto;}
# /* sc-component-id: mfogj7-1 */
# .eFFOlr{display:grid;grid-gap:10px;grid-template-columns:repeat(auto-fill,minmax(250px,1fr));}
# /* sc-component-id: mfogj7-2 */
# .flDmoO{border:1px solid #efefef;border-radius:4px;background-color:#fff;}
# /* sc-component-id: mfogj7-3 */
# .kmLNEA{width:100%;height:100%;object-fit:cover;}
# /* sc-component-id: mfogj7-4 */
# .lhOzej{padding:15px;}
# /* sc-component-id: mfogj7-5 */
# .bORnoA{font-size:20px;}
# /* sc-component-id: mfogj7-6 */
# .kyXXEd{color:rgba(0,0,0,.45);}
# /* sc-component-id: mfogj7-7 */
# .jYcHXG{width:100%;}
# /* sc-component-id: sc-1r8tg96-0 */
# .ibbaSH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;min-height:100vh;width:100%;padding-top:60px;background-color:rgb(250,250,250);}
# /* sc-component-id: sc-1r8tg96-1 */
# .kUDfDP{-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: kqh8nu-0 */
# .fGEdVE{margin:16px 0 10px;font-size:16px;color:rgba(0,0,0,.8);line-height:1;text-align:start;}
# /* sc-component-id: kqh8nu-1 */
# .cplMLf{margin-top:10px;}
# /* sc-component-id: s6s3mu-0 */
# .bhTAzw > div{width:500px;}
# /* sc-component-id: sc-8paben-0 */
# .gHRRXf{padding:16px;height:44px;padding:0 16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;} .gHRRXf > a{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-8paben-1 */
# .buAXMy{color:rgba(0,0,0,.95);font-size:18px;font-size:16px;font-weight:normal;}
# /* sc-component-id: sc-8paben-2 */
# .hVvjfI{margin:0 0 0 auto;}
# /* sc-component-id: gj72ok-0 */
# .dVtQdk{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;}
# /* sc-component-id: gj72ok-1 */
# .kOehyt{color:rgba(0,0,0,.95);font-size:18px;font-size:18px;font-weight:normal;}.fUpxcg{color:rgba(0,0,0,.95);font-size:18px;font-size:17px;font-weight:normal;}
# /* sc-component-id: gj72ok-2 */
# .btkBFS{color:rgba(0,0,0,.6);padding-top:0.8em;}.gGRou{color:rgba(0,0,0,.6);padding-top:0.8em;color:rgba(0,0,0,.35);}
# /* sc-component-id: sc-5lyygo-0 */
# .eOzFrE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background-color:#fff;min-height:100vh;}
# /* sc-component-id: sc-5lyygo-1 */
# .krlvRE{-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-1xqsgij-0 */
# .jvurF{padding:30px 0;border-bottom:1px solid rgba(0,0,0,0.05);}
# /* sc-component-id: sc-1xqsgij-1 */
# .hIPmSs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-1xqsgij-2 */
# .bWaNyC{-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-1xqsgij-4 */
# .iZkVmA{font-size:20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:10px 0;line-height:1;}
# /* sc-component-id: sc-1xqsgij-5 */
# .gNLohj{color:rgba(0,0,0,.45);font-size:16px;line-height:1.6;max-width:400px;}
# /* sc-component-id: sc-1xqsgij-6 */
# .etkHZs{margin-top:16px;font-size:16px;}
# /* sc-component-id: sc-1slh6gx-0 */
# .gvFcLj{margin-bottom:10px;} .gvFcLj:last-child{margin-bottom:0;} .gvFcLj p{-webkit-flex:1;-ms-flex:1;flex:1;line-height:37px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1slh6gx-5 */
# .gOQSgp{background:#49bd69;border-radius:100%;height:16px;width:16px;padding:1px;margin-left:8px;}
# /* sc-component-id: sc-1pict2x-0 */
# .dnwqEh{min-height:100vh;padding-top:60px;background-color:#fff;}
# /* sc-component-id: sc-1pict2x-1 */
# .hLsOTH{max-width:640px;margin:auto;padding:50px 0;}
# /* sc-component-id: sc-1pict2x-2 */
# .eMTMAs{font-size:32px;border-bottom:1px solid rgba(0,0,0,0.05);}
# /* sc-component-id: sc-63stfp-1 */
# .jZETev{position:relative;width:406px;margin:0 auto;border:1px solid #efefef;background-color:#fff;}
# /* sc-component-id: sc-63stfp-2 */
# .cyhjEi{height:93px;}
# /* sc-component-id: sc-63stfp-3 */
# .iqjPdO{font-size:20px;} .iqjPdO::-webkit-input-placeholder{font-size:13px;color:rgba(0,0,0,.45);} .iqjPdO::-moz-placeholder{font-size:13px;color:rgba(0,0,0,.45);} .iqjPdO:-ms-input-placeholder{font-size:13px;color:rgba(0,0,0,.45);} .iqjPdO::placeholder{font-size:13px;color:rgba(0,0,0,.45);}
# /* sc-component-id: sc-63stfp-4 */
# .fEgxQz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-size:18px;line-height:24px;margin-bottom:9px;}
# /* sc-component-id: sc-63stfp-5 */
# .kYKWjL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;font-size:14px;}
# /* sc-component-id: sc-63stfp-6 */
# .cEAwVA{cursor:pointer;}
# /* sc-component-id: vxn6zz-7 */
# .jHvFQB{position:relative;height:100vh;width:100vw;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;justify-items:center;background-color:#00324e;margin:0;padding:0;}
# /* sc-component-id: vxn6zz-8 */
# .kmKQkY{background-color:#006aa6;height:60px;position:fixed;width:100%;z-index:99;}
# /* sc-component-id: vxn6zz-9 */
# .kTKEpO{padding:0 20px;max-width:1240px;min-width:720px;width:100%;height:100%;margin:auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-content:flex-start;-ms-flex-line-pack:start;align-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: vxn6zz-10 */
# .jDpWuh{position:relative;font-size:18px;font-weight:normal;color:rgba(255,255,255,0.75);padding:0 16px 0 32px;line-height:32px;margin:0;} .jDpWuh:before{content:'';position:absolute;left:16px;height:32px;border-left:1px solid #fff;}
# /* sc-component-id: vxn6zz-11 */
# .inzeAt{-webkit-flex:1;-ms-flex:1;flex:1;width:100%;margin:60px auto 0;}
# /* sc-component-id: sc-1trf0uy-0 */
# .bntZuw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;height:100%;padding-top:20px;}
# /* sc-component-id: sc-1trf0uy-1 */
# .cJjVFx{-webkit-flex:1;-ms-flex:1;flex:1;margin:0 auto;max-width:728px;width:100%;}
# /* sc-component-id: sc-1trf0uy-2 */
# .gTdZmp{background:#fff;border-radius:4px 4px 0 0;border:none;width:100%;height:100%;}</style></head><body><div id="__next"><div class="sc-15zy2le-0 bUmARS"><div class="sc-1tl0s6i-0 gRRqRb"><div class="sc-1tl0s6i-1 bkKJCY"><a title="Dcard" class="lvor8b-0 jsnIlX" href="/f"><img src="/_next/static/images/logo-6c547910a47669647856d4c9cc62f0ba.svg" alt="Dcard" class="sc-1ywcn7k-0 gYUaPZ"/></a><div class="sc-15zy2le-1 DLzzZ"><div class="pw4e6a-0 ierzKU"><form><input type="search" placeholder="搜尋文章、看板、人物" name="query" aria-label="搜尋文章、看板、人物" class="sc-1ag928-0 kUMklR pw4e6a-1 fWARvU"/><button title="搜尋" class="pw4e6a-2 jMlptb"><span size="20" fill="#fff" class="ydgdj7-0 hhSnba pw4e6a-5 etwaaz" role="img"><svg viewBox="0 0 28 28"><path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z"/></svg></span></button><button type="submit" class="ksi2hf-0 eNbBFe"></button></form></div></div></div><div role="navigation" class="sc-1tl0s6i-2 pwVHE"><a role="button" class="u7yy6z-0 fnZGBW" href="/signup?redirect=%2Ff"><span class="u7yy6z-1 fxrSjZ">登入</span></a><div class="sc-1ykc0nb-2 iNRVSl"><a title="更多" role="button" class="u7yy6z-0 deAgGq"><span class="u7yy6z-1 fxrSjZ"><span fill="#fff" size="26" class="ydgdj7-0 gCQlMD u7yy6z-2 eFRAge" role="img"><svg viewBox="0 0 24 24"><path d="M11.08 15.62l-4.69-4.69a1.31 1.31 0 01.92-2.24h9.38a1.31 1.31 0 01.92 2.24l-4.69 4.69a1.3 1.3 0 01-1.84 0z"/><path fill="none" d="M0 0h24v24H0z"/></svg></span></span></a></div></div></div></div><div class="avchkw-0 lcIqKn"><div class="avchkw-1 dLkKRc"><div class="sc-19x83id-0 eqvIEe"><a href="/forum/all"><div class="sc-1yi4rc3-0 btuVdm"><div class="sc-19x83id-1 iqLTew"><span size="24" fill="#fff" class="ydgdj7-0 iYfIzd sc-19x83id-2 eJidNy" role="img"><svg viewBox="0 0 24 24"><path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum"/></svg></span></div><div class="sc-1vptqgj-1 fVjALD">所有看板</div></div></a><a href="/forum/popular"><div class="sc-1yi4rc3-0 btuVdm"><div class="sc-19x83id-1 iqLTew"><span size="24" fill="#fff" class="ydgdj7-0 iYfIzd sc-19x83id-2 eJidNy" role="img"><svg viewBox="0 0 24 24"><path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot"/></svg></span></div><div class="sc-1vptqgj-1 fVjALD">即時熱門看板</div></div></a><a href="/goods"><div class="sc-1yi4rc3-0 btuVdm"><div class="sc-19x83id-1 iqLTew"><span size="24" fill="#fff" class="ydgdj7-0 iYfIzd sc-5qff8c-0 jcFMFq" role="img"><svg viewBox="0 0 24 24"><path d="M8 21a2 2 0 11-2-2 2 2 0 012 2zm10-2a2 2 0 102 2 2 2 0 00-2-2zm2.44-1.19v-1a.5.5 0 00-.5-.5H6.3a.5.5 0 01-.4-.81L7.05 14a1 1 0 00.16-.93L4.48 4.72A1 1 0 004 4.13l-1.85-.9a.5.5 0 00-.67.23l-.48.9a.51.51 0 00.24.64l1.47.71 2.43 7.48-.82 1a2.49 2.49 0 00-.09 2.94 2.62 2.62 0 002.2 1.1h13.5a.51.51 0 00.5-.42zm1.35-7V6.38a2 2 0 00-2-2H9.23A2 2 0 007.3 6.92l1.82 5.8a2 2 0 002.3 1.43l8.74-1.33a2 2 0 001.62-1.97z"/></svg></span></div><div class="sc-1vptqgj-1 fVjALD">好物研究室</div></div></a><div class="wswqpf-0 ebZjiw ScrollbarsCustom" style="position:relative"><div class="wswqpf-1 IUuAe Scrollb ...
#       height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript><script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script id="__NEXT_DATA__" type="application/json">{"props":{"pageProps":{"layoutInitialProps":{"layoutInitialProps":{"layoutInitialProps":{},"componentInitialProps":{}},"componentInitialProps":{}},"componentInitialProps":{"query":{},"paginationOptions":{"forumAlias":"all"},"tabs":[{"uiType":"dropdown","alias":"all","name":"全部","listType":"legacy","uiPayload":{"dropdownItems":[{"uiType":"button","alias":"hot","name":"熱門","listType":"legacy","isHome":false},{"uiType":"button","alias":"latest","name":"最新","listType":"legacy","isHome":false}]},"isHome":false},{"uiType":"button","alias":"subscribe","name":"追蹤","listType":"legacy","isHome":false}],"isForumRulePage":false}},"isLogin":false,"isMobile":false,"initialState":{"adConfigs":{"data":{"hot_comments_hidden_post_authors":["dcardadangel","dcardecangel","dcardsvangel"],"post_engagement_idle":[],"post_engagement_interval":[],"web_adsenses":[{"id":"div-gpt-ad-1458631742813-0","name":"Desktop 右一","path":"/146730420/Desktop-Right-Top","sizes":[{"width":300,"height":250}]},{"id":"div-gpt-ad-1466065536619-0","name":"Desktop 右二(原臉書上方)","path":"/146730420/Desktop-Beyond-FB","sizes":[{"width":300,"height":250}]},{"id":"div-gpt-ad-1582095045953-0","name":"Desktop 右三摩天","path":"/146730420/Desktop-Right3","sizes":[{"width":300,"height":600}]},{"id":"div-gpt-ad-1582095257338-0","name":"Desktop 右四","path":"/146730420/Desktop-Right4","sizes":[{"width":300,"height":250}]},{"id":"div-gpt-ad-1458631598292-0","name":"Desktop 右下摩天","path":"/146730420/Desktop-RightBottom-Bottom","sizes":[{"width":300,"height":600}]},{"id":"div-gpt-ad-1574770247619-0","name":"Desktop 全部回應 (10,30)","path":"/146730420/Desktop-Comments","sizes":[{"width":728,"height":90}]},{"id":"div-gpt-ad-1467085023952-0","name":"Desktop 單篇文章底部","path":"/146730420/Desktop-Article-Bottom","sizes":[{"width":728,"height":90}]},{"id":"div-gpt-ad-1487138000089-0","name":"Mobile Web 文章底部 (new)","path":"/146730420/Mobile-Web-Article-End","sizes":[{"width":300,"height":250}]},{"id":"div-gpt-ad-1466051481599-0","name":"Mobile Web 人氣回應結束","path":"/146730420/Mweb-Popular-Comments","sizes":[{"width":300,"height":250}]},{"id":"div-gpt-ad-1470381102159-0","name":"Mobile Web 全部回應 (每 30 則)","path":"/146730420/Mweb-Comments","sizes":[{"width":300,"height":250}]},{"id":"div-gpt-ad-1458792275330-0","name":"Mobile Web 畫面底部","path":"/146730420/Mobile-Web-Screen-Bottom","sizes":[{"width":300,"height":250}]},{"id":"div-gpt-ad-1471245470448-0","name":"Mobile Web 畫面頂部","path":"/146730420/Mobile-Web-Screen-Top","sizes":[{"width":300,"height":250}]}]},"error":null,"loading":false,"fetched":true},"app":{"data":{"headers":{"cf-ipcountry":"TW","user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.132 Safari/537.36","cf-device-type":"desktop","x-cloud-trace-context":"d535fb1535ff13995fb6276464b52143/265617525090382775","true-client-ip":"123.241.46.76"},"isLogin":false,"isMobile":false,"userAgent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.132 Safari/537.36","ipCountry":"TW"},"error":null,"loading":false,"fetched":false},"auth":{"socialLogin":{}},"banner":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"channel":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{},"unread":0},"collection":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"comment":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"commentDraft":{"data":{},"error":null,"paginations":{}, ...

# %%
print('Request 取回之後該怎麼取出資料，資料型態是什麼？ =>')

print(type(r))
# Out:
# Request 取回之後該怎麼取出資料，資料型態是什麼？ =>
# <class 'requests.models.Response'>

# %%
print('為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ => ')
print("Beautiful Soup 是一個 Python 包，功能包括解析HTML、XML文件、修復含有未必合標籤等錯誤的文件。這個擴充包為待解析的頁面建立一棵樹，以便提取其中的資料")
soup = BeautifulSoup(r.text, "html5lib")
#print(soup)
print("處理後的型態是什麼？ => ",type(soup))
# Out:
# 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ =>
# Beautiful Soup 是一個 Python 包，功能包括解析HTML、XML文件、修復含有未必合標籤等錯誤的文件。這個擴充包為待解析的頁面建立一棵樹，以便提取其中的資料
# 處理後的型態是什麼？ =>  <class 'bs4.BeautifulSoup'>

# %% [markdown]
# ### 2. 知乎： https://www.zhihu.com/explore

# %%
url = 'https://www.zhihu.com/explore'
r = requests.get(url)
r.encoding = 'utf-8'

print(r)
# Out:
# <Response [400]>

# %% [markdown]
# ### 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %%
import requests
url = 'https://www.zhihu.com/explore'

headers = {'user-agent':'my-app/0.01'}
'''
Your Code Here
'''
r = requests.get(url,headers)

r.encoding = 'utf-8'
print(r.text[0:600])
