# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
import json
r = requests.get('https://api.github.com/events')
# r.text
print(r.text)
# json.loads(r.text)
json.loads(r.text)
# Out:
# [{"id":"11645345421","type":"PushEvent","actor":{"id":60491581,"login":"rodrigotaylorr","display_login":"rodrigotaylorr","gravatar_id":"","url":"https://api.github.com/users/rodrigotaylorr","avatar_url":"https://avatars.githubusercontent.com/u/60491581?"},"repo":{"id":241546301,"name":"JJFAO/grupo2CL","url":"https://api.github.com/repos/JJFAO/grupo2CL"},"payload":{"push_id":4700731091,"size":7,"distinct_size":3,"ref":"refs/heads/release-candidate-07022020","head":"279e47cc45f13f9268b082aaa47d5fad679d67cf","before":"65133b7ccdec326a3a2a6c3afc0a695151fb82b3","commits":[{"sha":"9ad8f26c4a32e8a2a6205a7bb8f98df5a7afc790","author":{"email":"rodrigo_taylorr@outlook.com","name":"Rodrigo Taylor"},"message":"Trabajando en cards con imagen","distinct":false,"url":"https://api.github.com/repos/JJFAO/grupo2CL/commits/9ad8f26c4a32e8a2a6205a7bb8f98df5a7afc790"},{"sha":"f73933892dd9e6d9bd6d418bdf1c624a85a7793b","author":{"email":"rodrigo_taylorr@outlook.com","name":"Rodrigo Taylor"},"message":"Se acomodo imagenes y se agrego desplegable","distinct":false,"url":"https://api.github.com/repos/JJFAO/grupo2CL/commits/f73933892dd9e6d9bd6d418bdf1c624a85a7793b"},{"sha":"ebceb42be7832698abff98f2e8a3eb9369270de9","author":{"email":"rodrigo_taylorr@outlook.com","name":"Rodrigo Taylor"},"message":"Se agrego titulo a la imagen principal","distinct":false,"url":"https://api.github.com/repos/JJFAO/grupo2CL/commits/ebceb42be7832698abff98f2e8a3eb9369270de9"},{"sha":"d57db62efa02e412861409582e9be4b01189a624","author":{"email":"rodrigo_taylorr@outlook.com","name":"Rodrigo Taylor"},"message":"Agregue fuentes y acomode formato escritorio","distinct":false,"url":"https://api.github.com/repos/JJFAO/grupo2CL/commits/d57db62efa02e412861409582e9be4b01189a624"},{"sha":"dd0b2dc0d94a27cb916b1873bfb9fa355f923bee","author":{"email":"rodrigo_taylorr@outlook.com","name":"Rodrigo Taylor"},"message":"Se termino el body de la homepage","distinct":true,"url":"https://api.github.com/repos/JJFAO/grupo2CL/commits/dd0b2dc0d94a27cb916b1873bfb9fa355f923bee"},{"sha":"895fb707f0dc5973458f06b71711c76c7b021441","author":{"email":"rodrigo_taylorr@outlook.com","name":"Rodrigo Taylor"},"message":"Merge branch 'G2-homepagebody' into release-candidate-07022020","distinct":true,"url":"https://api.github.com/repos/JJFAO/grupo2CL/commits/895fb707f0dc5973458f06b71711c76c7b021441"},{"sha":"279e47cc45f13f9268b082aaa47d5fad679d67cf","author":{"email":"rodrigo_taylorr@outlook.com","name":"Rodrigo Taylor"},"message":"Merge branch 'release-candidate-07022020' of https://github.com/JJFAO/grupo2CL into release-candidate-07022020","distinct":true,"url":"https://api.github.com/repos/JJFAO/grupo2CL/commits/279e47cc45f13f9268b082aaa47d5fad679d67cf"}]},"public":true,"created_at":"2020-03-01T00:39:48Z"},{"id":"11645345419","type":"PushEvent","actor":{"id":2512748,"login":"cjihrig","display_login":"cjihrig","gravatar_id":"","url":"https://api.github.com/users/cjihrig","avatar_url":"https://avatars.githubusercontent.com/u/2512748?"},"repo":{"id":240633874,"name":"cjihrig/gelfie","url":"https://api.github.com/repos/cjihrig/gelfie"},"payload":{"push_id":4700731090,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"6423e7c9241f52cf2a250238e662b08056dc3ea2","before":"7584747c63547a979699df5073e58c8964c08330","commits":[{"sha":"6423e7c9241f52cf2a250238e662b08056dc3ea2","author":{"email":"cjihrig@gmail.com","name":"cjihrig"},"message":"move from travis to github actions","distinct":true,"url":"https://api.github.com/repos/cjihrig/gelfie/commits/6423e7c9241f52cf2a250238e662b08056dc3ea2"}]},"public":true,"created_at":"2020-03-01T00:39:48Z"},{"id":"11645345408","type":"CreateEvent","actor":{"id":35711944,"login":"ethanonstott","display_login":"ethanonstott","gravatar_id":"","url":"https://api.github.com/users/ethanonstott","avatar_url":"https://avatars.githubusercontent.com/u/35711944?"},"repo":{"id":244063604,"name":"ethanonstott/ethanonstott.dev","url":"https://api.github.com/repos/ethanonstott/ethanonstott.de ...
# [{'id': '11645345421',
#   'type': 'PushEvent',
#   'actor': {'id': 60491581,
#    'login': 'rodrigotaylorr',
#    'display_login': 'rodrigotaylorr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rodrigotaylorr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60491581?'},
#   'repo': {'id': 241546301,
#    'name': 'JJFAO/grupo2CL',
#    'url': 'https://api.github.com/repos/JJFAO/grupo2CL'},
#   'payload': {'push_id': 4700731091,
#    'size': 7,
#    'distinct_size': 3,
#    'ref': 'refs/heads/release-candidate-07022020',
#    'head': '279e47cc45f13f9268b082aaa47d5fad679d67cf',
#    'before': '65133b7ccdec326a3a2a6c3afc0a695151fb82b3',
#    'commits': [{'sha': '9ad8f26c4a32e8a2a6205a7bb8f98df5a7afc790',
#      'author': {'email': 'rodrigo_taylorr@outlook.com',
#       'name': 'Rodrigo Taylor'},
#      'message': 'Trabajando en cards con imagen',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/JJFAO/grupo2CL/commits/9ad8f26c4a32e8a2a6205a7bb8f98df5a7afc790'},
#     {'sha': 'f73933892dd9e6d9bd6d418bdf1c624a85a7793b',
#      'author': {'email': 'rodrigo_taylorr@outlook.com',
#       'name': 'Rodrigo Taylor'},
#      'message': 'Se acomodo imagenes y se agrego desplegable',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/JJFAO/grupo2CL/commits/f73933892dd9e6d9bd6d418bdf1c624a85a7793b'},
#     {'sha': 'ebceb42be7832698abff98f2e8a3eb9369270de9',
#      'author': {'email': 'rodrigo_taylorr@outlook.com',
#       'name': 'Rodrigo Taylor'},
#      'message': 'Se agrego titulo a la imagen principal',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/JJFAO/grupo2CL/commits/ebceb42be7832698abff98f2e8a3eb9369270de9'},
#     {'sha': 'd57db62efa02e412861409582e9be4b01189a624',
#      'author': {'email': 'rodrigo_taylorr@outlook.com',
#       'name': 'Rodrigo Taylor'},
#      'message': 'Agregue fuentes y acomode formato escritorio',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/JJFAO/grupo2CL/commits/d57db62efa02e412861409582e9be4b01189a624'},
#     {'sha': 'dd0b2dc0d94a27cb916b1873bfb9fa355f923bee',
#      'author': {'email': 'rodrigo_taylorr@outlook.com',
#       'name': 'Rodrigo Taylor'},
#      'message': 'Se termino el body de la homepage',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JJFAO/grupo2CL/commits/dd0b2dc0d94a27cb916b1873bfb9fa355f923bee'},
#     {'sha': '895fb707f0dc5973458f06b71711c76c7b021441',
#      'author': {'email': 'rodrigo_taylorr@outlook.com',
#       'name': 'Rodrigo Taylor'},
#      'message': "Merge branch 'G2-homepagebody' into release-candidate-07022020",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JJFAO/grupo2CL/commits/895fb707f0dc5973458f06b71711c76c7b021441'},
#     {'sha': '279e47cc45f13f9268b082aaa47d5fad679d67cf',
#      'author': {'email': 'rodrigo_taylorr@outlook.com',
#       'name': 'Rodrigo Taylor'},
#      'message': "Merge branch 'release-candidate-07022020' of https://github.com/JJFAO/grupo2CL into release-candidate-07022020",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JJFAO/grupo2CL/commits/279e47cc45f13f9268b082aaa47d5fad679d67cf'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:48Z'},
#  {'id': '11645345419',
#   'type': 'PushEvent',
#   'actor': {'id': 2512748,
#    'login': 'cjihrig',
#    'display_login': 'cjihrig',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cjihrig',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2512748?'},
#   'repo': {'id': 240633874,
#    'name': 'cjihrig/gelfie',
#    'url': 'https://api.github.com/repos/cjihrig/gelfie'},
#   'payload': {'push_id': 4700731090,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6423e7c9241f52cf2a250238e662b08056dc3ea2',
#    'before': '7584747c63547a979699df5073e58c8964c08330',
#    'commits': [{'sha': '6423e7c9241f52cf2a250238e662b08056dc3ea2',
#      'author': {'email': 'cjihrig@gmail.com', 'name': 'cjihrig'},
#      'message': 'move from travis to github actions',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cjihrig/gelfie/commits/6423e7c9241f52cf2a250238e662b08056dc3ea2'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:48Z'},
#  {'id': '11645345408',
#   'type': 'CreateEvent',
#   'actor': {'id': 35711944,
#    'login': 'ethanonstott',
#    'display_login': 'ethanonstott',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ethanonstott',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35711944?'},
#   'repo': {'id': 244063604,
#    'name': 'ethanonstott/ethanonstott.dev',
#    'url': 'https://api.github.com/repos/ethanonstott/ethanonstott.dev'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'My Website',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T00:39:48Z'},
#  {'id': '11645345404',
#   'type': 'PushEvent',
#   'actor': {'id': 945128,
#    'login': 'bdhowald',
#    'display_login': 'bdhowald',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bdhowald',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/945128?'},
#   'repo': {'id': 132546155,
#    'name': 'bdhowald/hows_my_driving',
#    'url': 'https://api.github.com/repos/bdhowald/hows_my_driving'},
#   'payload': {'push_id': 4700731083,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7ee99219ad7538f64d7692e8d0bed8fbb769fefd',
#    'before': '166bd868a3e42df72a6a4ae8af2654a56f54896a',
#    'commits': [{'sha': '7ee99219ad7538f64d7692e8d0bed8fbb769fefd',
#      'author': {'email': 'bdhowald@gmail.com', 'name': 'Brian Howald'},
#      'message': 'Fixing retrospective job for leap days.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bdhowald/hows_my_driving/commits/7ee99219ad7538f64d7692e8d0bed8fbb769fefd'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:48Z'},
#  {'id': '11645345406',
#   'type': 'CreateEvent',
#   'actor': {'id': 61524718,
#    'login': 'justin-tin',
#    'display_login': 'justin-tin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/justin-tin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61524718?'},
#   'repo': {'id': 244063597,
#    'name': 'justin-tin/cv',
#    'url': 'https://api.github.com/repos/justin-tin/cv'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T00:39:48Z'},
#  {'id': '11645345396',
#   'type': 'PushEvent',
#   'actor': {'id': 61637772,
#    'login': 'takeyama29',
#    'display_login': 'takeyama29',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/takeyama29',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61637772?'},
#   'repo': {'id': 244055946,
#    'name': 'takeyama29/hangman',
#    'url': 'https://api.github.com/repos/takeyama29/hangman'},
#   'payload': {'push_id': 4700731077,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'bab8d9ae6f237395c9fe84f43311c40bcec7c5fe',
#    'before': '7d9be24aa2f1d8929d17e8419ee523c56829d9c6',
#    'commits': [{'sha': 'bab8d9ae6f237395c9fe84f43311c40bcec7c5fe',
#      'author': {'email': 't29.qxp@gmail.com', 'name': 'takeyama29'},
#      'message': 'Delete hangman.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/takeyama29/hangman/commits/bab8d9ae6f237395c9fe84f43311c40bcec7c5fe'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:48Z'},
#  {'id': '11645345398',
#   'type': 'GollumEvent',
#   'actor': {'id': 23490060,
#    'login': 'r00t-3xp10it',
#    'display_login': 'r00t-3xp10it',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/r00t-3xp10it',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23490060?'},
#   'repo': {'id': 242379387,
#    'name': 'r00t-3xp10it/meterpeter',
#    'url': 'https://api.github.com/repos/r00t-3xp10it/meterpeter'},
#   'payload': {'pages': [{'page_name': 'working-with-meterpeter-Builtin-keylogger',
#      'title': 'working with meterpeter Builtin keylogger',
#      'summary': None,
#      'action': 'edited',
#      'sha': 'cb2e4611531ec3f9ddc3b7fbcc752b9db7ab72fd',
#      'html_url': 'https://github.com/r00t-3xp10it/meterpeter/wiki/working-with-meterpeter-Builtin-keylogger'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:48Z'},
#  {'id': '11645345391',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 32440971,
#    'login': 'Pwnagebird',
#    'display_login': 'Pwnagebird',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Pwnagebird',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32440971?'},
#   'repo': {'id': 232220550,
#    'name': 'Pwnagebird/ConcordiaGO',
#    'url': 'https://api.github.com/repos/Pwnagebird/ConcordiaGO'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/Pwnagebird/ConcordiaGO/issues/33',
#     'repository_url': 'https://api.github.com/repos/Pwnagebird/ConcordiaGO',
#     'labels_url': 'https://api.github.com/repos/Pwnagebird/ConcordiaGO/issues/33/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Pwnagebird/ConcordiaGO/issues/33/comments',
#     'events_url': 'https://api.github.com/repos/Pwnagebird/ConcordiaGO/issues/33/events',
#     'html_url': 'https://github.com/Pwnagebird/ConcordiaGO/issues/33',
#     'id': 549160729,
#     'node_id': 'MDU6SXNzdWU1NDkxNjA3Mjk=',
#     'number': 33,
#     'title': 'Place to Place Outdoor Directions',
#     'user': {'login': 'Pwnagebird',
#      'id': 32440971,
#      'node_id': 'MDQ6VXNlcjMyNDQwOTcx',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/32440971?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Pwnagebird',
#      'html_url': 'https://github.com/Pwnagebird',
#      'followers_url': 'https://api.github.com/users/Pwnagebird/followers',
#      'following_url': 'https://api.github.com/users/Pwnagebird/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Pwnagebird/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Pwnagebird/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Pwnagebird/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Pwnagebird/orgs',
#      'repos_url': 'https://api.github.com/users/Pwnagebird/repos',
#      'events_url': 'https://api.github.com/users/Pwnagebird/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Pwnagebird/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1785898431,
#       'node_id': 'MDU6TGFiZWwxNzg1ODk4NDMx',
#       'url': 'https://api.github.com/repos/Pwnagebird/ConcordiaGO/labels/P1',
#       'name': 'P1',
#       'color': 'FF0000',
#       'default': False,
#       'description': 'High-Medium Priority'},
#      {'id': 1783539253,
#       'node_id': 'MDU6TGFiZWwxNzgzNTM5MjUz',
#       'url': 'https://api.github.com/repos/Pwnagebird/ConcordiaGO/labels/User%20Story',
#       'name': 'User Story',
#       'color': '96fc4e',
#       'default': False,
#       'description': 'User Story Ticket'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'Debnam',
#      'id': 25811726,
#      'node_id': 'MDQ6VXNlcjI1ODExNzI2',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/25811726?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Debnam',
#      'html_url': 'https://github.com/Debnam',
#      'followers_url': 'https://api.github.com/users/Debnam/followers',
#      'following_url': 'https://api.github.com/users/Debnam/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Debnam/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Debnam/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Debnam/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Debnam/orgs',
#      'repos_url': 'https://api.github.com/users/Debnam/repos',
#      'events_url': 'https://api.github.com/users/Debnam/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Debnam/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'Debnam',
#       'id': 25811726,
#       'node_id': 'MDQ6VXNlcjI1ODExNzI2',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/25811726?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Debnam',
#       'html_url': 'https://github.com/Debnam',
#       'followers_url': 'https://api.github.com/users/Debnam/followers',
#       'following_url': 'https://api.github.com/users/Debnam/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Debnam/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Debnam/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Debnam/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Debnam/orgs',
#       'repos_url': 'https://api.github.com/users/Debnam/repos',
#       'events_url': 'https://api.github.com/users/Debnam/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Debnam/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'MoreWaqar',
#       'id': 35977219,
#       'node_id': 'MDQ6VXNlcjM1OTc3MjE5',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/35977219?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/MoreWaqar',
#       'html_url': 'https://github.com/MoreWaqar',
#       'followers_url': 'https://api.github.com/users/MoreWaqar/followers',
#       'following_url': 'https://api.github.com/users/MoreWaqar/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/MoreWaqar/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/MoreWaqar/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/MoreWaqar/subscriptions',
#       'organizations_url': 'https://api.github.com/users/MoreWaqar/orgs',
#       'repos_url': 'https://api.github.com/users/MoreWaqar/repos',
#       'events_url': 'https://api.github.com/users/MoreWaqar/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/MoreWaqar/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': {'url': 'https://api.github.com/repos/Pwnagebird/ConcordiaGO/milestones/2',
#      'html_url': 'https://github.com/Pwnagebird/ConcordiaGO/milestone/2',
#      'labels_url': 'https://api.github.com/repos/Pwnagebird/ConcordiaGO/milestones/2/labels',
#      'id': 4992764,
#      'node_id': 'MDk6TWlsZXN0b25lNDk5Mjc2NA==',
#      'number': 2,
#      'title': 'Sprint #2',
#      'description': '',
#      'creator': {'login': 'Pwnagebird',
#       'id': 32440971,
#       'node_id': 'MDQ6VXNlcjMyNDQwOTcx',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/32440971?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Pwnagebird',
#       'html_url': 'https://github.com/Pwnagebird',
#       'followers_url': 'https://api.github.com/users/Pwnagebird/followers',
#       'following_url': 'https://api.github.com/users/Pwnagebird/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Pwnagebird/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Pwnagebird/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Pwnagebird/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Pwnagebird/orgs',
#       'repos_url': 'https://api.github.com/users/Pwnagebird/repos',
#       'events_url': 'https://api.github.com/users/Pwnagebird/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Pwnagebird/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 2,
#      'closed_issues': 4,
#      'state': 'open',
#      'created_at': '2020-01-09T22:35:45Z',
#      'updated_at': '2020-02-29T21:18:41Z',
#      'due_on': '2020-03-01T08:00:00Z',
#      'closed_at': None},
#     'comments': 2,
#     'created_at': '2020-01-13T20:24:04Z',
#     'updated_at': '2020-03-01T00:39:47Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'body': '# User Story \r\n\r\n## WHO/WHAT/WHY\r\n* As a user, I want to be able to get outdoor directions from place to place.\r\n\r\n## ACCEPTANCE CRITERIA\r\n* Show directions from any building to any building using google maps.\r\n* Show the directions via the map\r\n* Show another view to list the steps how to get there\r\n* User can cancel the trip \r\n* User can complete the trip \r\n\r\n## IMPLEMENTATION NOTES\r\n\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/Pwnagebird/ConcordiaGO/issues/comments/593023648',
#     'html_url': 'https://github.com/Pwnagebird/ConcordiaGO/issues/33#issuecomment-593023648',
#     'issue_url': 'https://api.github.com/repos/Pwnagebird/ConcordiaGO/issues/33',
#     'id': 593023648,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5MzAyMzY0OA==',
#     'user': {'login': 'Pwnagebird',
#      'id': 32440971,
#      'node_id': 'MDQ6VXNlcjMyNDQwOTcx',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/32440971?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Pwnagebird',
#      'html_url': 'https://github.com/Pwnagebird',
#      'followers_url': 'https://api.github.com/users/Pwnagebird/followers',
#      'following_url': 'https://api.github.com/users/Pwnagebird/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Pwnagebird/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Pwnagebird/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Pwnagebird/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Pwnagebird/orgs',
#      'repos_url': 'https://api.github.com/users/Pwnagebird/repos',
#      'events_url': 'https://api.github.com/users/Pwnagebird/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Pwnagebird/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-03-01T00:39:47Z',
#     'updated_at': '2020-03-01T00:39:47Z',
#     'author_association': 'OWNER',
#     'body': 'Acceptance Testing Passed ✔️\r\n\r\n* Show directions from any building to any building using google maps. ✔️\r\n* Show the directions via the map ✔️\r\n* Show another view to list the steps how to get there ✔️\r\n* User can cancel the trip ✔️\r\n* User can complete the trip✔️\r\n\r\nLooks all good. Search feature next sprint will definetly let us test this better'}},
#   'public': True,
#   'created_at': '2020-03-01T00:39:48Z'},
#  {'id': '11645345389',
#   'type': 'PushEvent',
#   'actor': {'id': 17038786,
#    'login': 'peter0530',
#    'display_login': 'peter0530',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/peter0530',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17038786?'},
#   'repo': {'id': 239459953,
#    'name': 'peter0530/maskdata-backup',
#    'url': 'https://api.github.com/repos/peter0530/maskdata-backup'},
#   'payload': {'push_id': 4700731070,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5bc238cd676bcbff9632d5aa4a96cb96a88c8812',
#    'before': 'f9d1dfcbc0e027239fc3c45303de868d471650b3',
#    'commits': [{'sha': '5bc238cd676bcbff9632d5aa4a96cb96a88c8812',
#      'author': {'email': 'a1515twtw@gmail.com', 'name': 'peter0530'},
#      'message': 'update 2020-03-01 08:39:39',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/peter0530/maskdata-backup/commits/5bc238cd676bcbff9632d5aa4a96cb96a88c8812'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:48Z'},
#  {'id': '11645345386',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46596436,
#    'name': 'Lombiq/Orchard-Download-As',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-Download-As'},
#   'payload': {'push_id': 4700731068,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/BTLR-54',
#    'head': '14fc1bf9666b42c7f4a6cdead36706ac1be28cd2',
#    'before': '14fc1bf9666b42c7f4a6cdead36706ac1be28cd2',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11645345385',
#   'type': 'PushEvent',
#   'actor': {'id': 8204522,
#    'login': 'ethan-campbell',
#    'display_login': 'ethan-campbell',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ethan-campbell',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8204522?'},
#   'repo': {'id': 129450243,
#    'name': 'ethan-campbell/Miscellaneous',
#    'url': 'https://api.github.com/repos/ethan-campbell/Miscellaneous'},
#   'payload': {'push_id': 4700731064,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '27e0e747b6a247b8abbcb600e8a6a8d93d86c9b0',
#    'before': '1a8fe35852b69573184d5801676a0f44acba6fee',
#    'commits': [{'sha': '27e0e747b6a247b8abbcb600e8a6a8d93d86c9b0',
#      'author': {'email': 'ethancc@uw.edu', 'name': 'Ethan Campbell'},
#      'message': "Tracking Kohaku's recovery from FIP",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ethan-campbell/Miscellaneous/commits/27e0e747b6a247b8abbcb600e8a6a8d93d86c9b0'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z'},
#  {'id': '11645345384',
#   'type': 'PushEvent',
#   'actor': {'id': 61067632,
#    'login': 'phj9059',
#    'display_login': 'phj9059',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phj9059',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61067632?'},
#   'repo': {'id': 240604691,
#    'name': 'phj9059/darkbot2',
#    'url': 'https://api.github.com/repos/phj9059/darkbot2'},
#   'payload': {'push_id': 4700731065,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a207450854352f0af6a7d16b7b907adab706fa99',
#    'before': '75b4df5b61fa5ff8ddde9e6cbd653db8272d855b',
#    'commits': [{'sha': 'a207450854352f0af6a7d16b7b907adab706fa99',
#      'author': {'email': '61067632+phj9059@users.noreply.github.com',
#       'name': 'phj9059'},
#      'message': 'bossDB',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/phj9059/darkbot2/commits/a207450854352f0af6a7d16b7b907adab706fa99'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z'},
#  {'id': '11645345383',
#   'type': 'DeleteEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 134017727,
#    'name': 'CesarDenis/numerology-calculator',
#    'url': 'https://api.github.com/repos/CesarDenis/numerology-calculator'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/react-dev-utils-5.0.2',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z'},
#  {'id': '11645345379',
#   'type': 'PushEvent',
#   'actor': {'id': 909587,
#    'login': 'felixbuenemann',
#    'display_login': 'felixbuenemann',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/felixbuenemann',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/909587?'},
#   'repo': {'id': 89668997,
#    'name': 'plexdrive/plexdrive',
#    'url': 'https://api.github.com/repos/plexdrive/plexdrive'},
#   'payload': {'push_id': 4700731059,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e205113c294b8cc4823d6a9d4818bfe816883e00',
#    'before': 'afa5e4e8c125e2758398dc72ab19dc7ea74e1a8c',
#    'commits': [{'sha': 'e205113c294b8cc4823d6a9d4818bfe816883e00',
#      'author': {'email': 'buenemann@louis.info', 'name': 'Felix Bünemann'},
#      'message': 'Remove allow_root option from README\n\nThis option was removed in #340.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/plexdrive/plexdrive/commits/e205113c294b8cc4823d6a9d4818bfe816883e00'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z',
#   'org': {'id': 61623885,
#    'login': 'plexdrive',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/plexdrive',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61623885?'}},
#  {'id': '11645345378',
#   'type': 'PushEvent',
#   'actor': {'id': 39992,
#    'login': 'gr2m',
#    'display_login': 'gr2m',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gr2m',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39992?'},
#   'repo': {'id': 194945502,
#    'name': 'octokit/auth-basic.js',
#    'url': 'https://api.github.com/repos/octokit/auth-basic.js'},
#   'payload': {'push_id': 4700731060,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '0e5a6c2949dba9edc396490d10717fdb92a13e17',
#    'before': 'c16c96ea5cbd33a46f0055745963534c4e18757f',
#    'commits': [{'sha': 'fd1c5fb778e5063edbcc9db138a41a1427372bf5',
#      'author': {'email': '23040076+greenkeeper[bot]@users.noreply.github.com',
#       'name': 'greenkeeper[bot]'},
#      'message': 'chore(package): update fetch-mock to version 9.0.0',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/octokit/auth-basic.js/commits/fd1c5fb778e5063edbcc9db138a41a1427372bf5'},
#     {'sha': '0e5a6c2949dba9edc396490d10717fdb92a13e17',
#      'author': {'email': '23040076+greenkeeper[bot]@users.noreply.github.com',
#       'name': 'greenkeeper[bot]'},
#      'message': 'chore(package): update lockfile package-lock.json',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/octokit/auth-basic.js/commits/0e5a6c2949dba9edc396490d10717fdb92a13e17'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z',
#   'org': {'id': 3430433,
#    'login': 'octokit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/octokit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3430433?'}},
#  {'id': '11645345372',
#   'type': 'PushEvent',
#   'actor': {'id': 59721975,
#    'login': 'iyuepei',
#    'display_login': 'iyuepei',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iyuepei',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59721975?'},
#   'repo': {'id': 241001965,
#    'name': 'iyuepei/iyuepei.github.io',
#    'url': 'https://api.github.com/repos/iyuepei/iyuepei.github.io'},
#   'payload': {'push_id': 4700731053,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ce4c089c4cddc1cd4974a1e5a917c638b5e84e65',
#    'before': 'c734b13d21cb6ad890f46bc764b4b08644aae085',
#    'commits': [{'sha': 'ce4c089c4cddc1cd4974a1e5a917c638b5e84e65',
#      'author': {'email': 'runner@Mac-1499.local', 'name': 'runner'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/iyuepei/iyuepei.github.io/commits/ce4c089c4cddc1cd4974a1e5a917c638b5e84e65'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z'},
#  {'id': '11645345368',
#   'type': 'PushEvent',
#   'actor': {'id': 46536452,
#    'login': 'nato-x',
#    'display_login': 'nato-x',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nato-x',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46536452?'},
#   'repo': {'id': 243769740,
#    'name': 'tryber/sd-03-block5-project-meme-generator',
#    'url': 'https://api.github.com/repos/tryber/sd-03-block5-project-meme-generator'},
#   'payload': {'push_id': 4700731052,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/renato-meme-generator-project',
#    'head': '22273f07973c37804dad4518b2b3e43b1abb9d76',
#    'before': 'd8800fd060c6484ac839262664b786216e515d3e',
#    'commits': [{'sha': '22273f07973c37804dad4518b2b3e43b1abb9d76',
#      'author': {'email': 'alvares.renato@hotmail.com', 'name': 'natox'},
#      'message': 'placing full image on container',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tryber/sd-03-block5-project-meme-generator/commits/22273f07973c37804dad4518b2b3e43b1abb9d76'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z',
#   'org': {'id': 55410300,
#    'login': 'tryber',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/tryber',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55410300?'}},
#  {'id': '11645345369',
#   'type': 'DeleteEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 134017727,
#    'name': 'CesarDenis/numerology-calculator',
#    'url': 'https://api.github.com/repos/CesarDenis/numerology-calculator'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/eslint-loader-2.2.1',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z'},
#  {'id': '11645345367',
#   'type': 'DeleteEvent',
#   'actor': {'id': 17939106,
#    'login': 'luuductrung1234',
#    'display_login': 'luuductrung1234',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/luuductrung1234',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17939106?'},
#   'repo': {'id': 241552456,
#    'name': 'luuductrung1234/learning-hub',
#    'url': 'https://api.github.com/repos/luuductrung1234/learning-hub'},
#   'payload': {'ref': 'jmeter', 'ref_type': 'branch', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z'},
#  {'id': '11645345366',
#   'type': 'DeleteEvent',
#   'actor': {'id': 39992,
#    'login': 'gr2m',
#    'display_login': 'gr2m',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gr2m',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39992?'},
#   'repo': {'id': 194945502,
#    'name': 'octokit/auth-basic.js',
#    'url': 'https://api.github.com/repos/octokit/auth-basic.js'},
#   'payload': {'ref': 'greenkeeper/fetch-mock-9.0.0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z',
#   'org': {'id': 3430433,
#    'login': 'octokit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/octokit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3430433?'}},
#  {'id': '11645345360',
#   'type': 'PushEvent',
#   'actor': {'id': 61632960,
#    'login': 'lemisa32434',
#    'display_login': 'lemisa32434',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lemisa32434',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61632960?'},
#   'repo': {'id': 244027939,
#    'name': 'lemisa32434/Fuck-me-honey-with-your-boner-2',
#    'url': 'https://api.github.com/repos/lemisa32434/Fuck-me-honey-with-your-boner-2'},
#   'payload': {'push_id': 4700731044,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c71ab57f4d6e8187a2316926d4a01ec66fbde6a1',
#    'before': 'ab32289a5bca176259767bf80f0590ee7c578691',
#    'commits': [{'sha': 'c71ab57f4d6e8187a2316926d4a01ec66fbde6a1',
#      'author': {'email': '61632960+lemisa32434@users.noreply.github.com',
#       'name': 'lemisa32434'},
#      'message': "Add files via upload\n\nHey Love..I'm 28 Yrs Naughty cute sexy girl. Just want to a guy to go down and eat my pussy❓Shaved and sweet.I Love sex 💗I can host \r\nand visit your place and car call available.I'm able come to your area like your house or hotel or others house👉If You Interested then...\r\n 📞Shower sex with mant position👉Doggy Style Fuck & Full Night Enjoy💯Oral, Anal 69 poisition👉Special BBJ 👉Penis massage Penis Suck😍Long \r\nTime Travel Specialy😛Fuck your own style any place Available 24/7 Hours😼 Contact Me Now..... http://3.120.146.135/Annabelle323",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lemisa32434/Fuck-me-honey-with-your-boner-2/commits/c71ab57f4d6e8187a2316926d4a01ec66fbde6a1'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z'},
#  {'id': '11645345363',
#   'type': 'PushEvent',
#   'actor': {'id': 17193977,
#    'login': 'newstools',
#    'display_login': 'newstools',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/newstools',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17193977?'},
#   'repo': {'id': 231168693,
#    'name': 'newstools/2020-the-sun-nigeria',
#    'url': 'https://api.github.com/repos/newstools/2020-the-sun-nigeria'},
#   'payload': {'push_id': 4700731048,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '598032c9ac9a5bd73fb9bfaf4f3c2c8dd5d5540a',
#    'before': '3505d7f6a1d71f1e1f60c21bb19a8f4054aae076',
#    'commits': [{'sha': '598032c9ac9a5bd73fb9bfaf4f3c2c8dd5d5540a',
#      'author': {'email': 'github@newstools.co.za', 'name': 'NewsTools'},
#      'message': 'Created Text For URL [www.sunnewsonline.com/enugu-lg-elections-witness-poor-turnout-but-peaceful/]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/newstools/2020-the-sun-nigeria/commits/598032c9ac9a5bd73fb9bfaf4f3c2c8dd5d5540a'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z'},
#  {'id': '11645345365',
#   'type': 'WatchEvent',
#   'actor': {'id': 4212985,
#    'login': 'stjordanis',
#    'display_login': 'stjordanis',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stjordanis',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4212985?'},
#   'repo': {'id': 54173593,
#    'name': 'storybookjs/storybook',
#    'url': 'https://api.github.com/repos/storybookjs/storybook'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z',
#   'org': {'id': 22632046,
#    'login': 'storybookjs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/storybookjs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22632046?'}},
#  {'id': '11645345362',
#   'type': 'CreateEvent',
#   'actor': {'id': 10249642,
#    'login': 'anurtayev',
#    'display_login': 'anurtayev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anurtayev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10249642?'},
#   'repo': {'id': 244063601,
#    'name': 'anurtayev/nfl-rushing',
#    'url': 'https://api.github.com/repos/anurtayev/nfl-rushing'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z'},
#  {'id': '11645345359',
#   'type': 'DeleteEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 134017727,
#    'name': 'CesarDenis/numerology-calculator',
#    'url': 'https://api.github.com/repos/CesarDenis/numerology-calculator'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/css-loader-0.28.11',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z'},
#  {'id': '11645345357',
#   'type': 'DeleteEvent',
#   'actor': {'id': 38846746,
#    'login': 'nbspou-bot',
#    'display_login': 'nbspou-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nbspou-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38846746?'},
#   'repo': {'id': 47583743,
#    'name': 'ryzom/ryzomcore',
#    'url': 'https://api.github.com/repos/ryzom/ryzomcore'},
#   'payload': {'ref': 'ryzomcore/v0.9.0',
#    'ref_type': 'tag',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z',
#   'org': {'id': 16198420,
#    'login': 'ryzom',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ryzom',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16198420?'}},
#  {'id': '11645345356',
#   'type': 'DeleteEvent',
#   'actor': {'id': 47944500,
#    'login': 'benjamin-guibert',
#    'display_login': 'benjamin-guibert',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/benjamin-guibert',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47944500?'},
#   'repo': {'id': 184791113,
#    'name': 'benjamin-guibert/budget-server',
#    'url': 'https://api.github.com/repos/benjamin-guibert/budget-server'},
#   'payload': {'ref': 'develop', 'ref_type': 'branch', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z'},
#  {'id': '11645345353',
#   'type': 'PushEvent',
#   'actor': {'id': 8216020,
#    'login': 'GavinEke',
#    'display_login': 'GavinEke',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GavinEke',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8216020?'},
#   'repo': {'id': 243127753,
#    'name': 'GavinEke/SpaceshipVoyager',
#    'url': 'https://api.github.com/repos/GavinEke/SpaceshipVoyager'},
#   'payload': {'push_id': 4700731043,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '28456f5e353d2e7bc11c762a252d5ad45a557a48',
#    'before': 'f8c3272318a509f4ff057cdcf7ac1f1635498fd6',
#    'commits': [{'sha': '28456f5e353d2e7bc11c762a252d5ad45a557a48',
#      'author': {'email': 'GavinEke@users.noreply.github.com',
#       'name': 'Gavin Eke'},
#      'message': 'Add Content Security Policy',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/GavinEke/SpaceshipVoyager/commits/28456f5e353d2e7bc11c762a252d5ad45a557a48'}]},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z'},
#  {'id': '11645345354',
#   'type': 'DeleteEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 134017727,
#    'name': 'CesarDenis/numerology-calculator',
#    'url': 'https://api.github.com/repos/CesarDenis/numerology-calculator'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/raf-3.4.1',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z'},
#  {'id': '11645345352',
#   'type': 'ForkEvent',
#   'actor': {'id': 25602703,
#    'login': 'belligerant',
#    'display_login': 'belligerant',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/belligerant',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25602703?'},
#   'repo': {'id': 66319383,
#    'name': 'andrewbanchich/forty-jekyll-theme',
#    'url': 'https://api.github.com/repos/andrewbanchich/forty-jekyll-theme'},
#   'payload': {'forkee': {'id': 244063600,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyNDQwNjM2MDA=',
#     'name': 'forty-jekyll-theme',
#     'full_name': 'belligerant/forty-jekyll-theme',
#     'private': False,
#     'owner': {'login': 'belligerant',
#      'id': 25602703,
#      'node_id': 'MDQ6VXNlcjI1NjAyNzAz',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/25602703?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/belligerant',
#      'html_url': 'https://github.com/belligerant',
#      'followers_url': 'https://api.github.com/users/belligerant/followers',
#      'following_url': 'https://api.github.com/users/belligerant/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/belligerant/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/belligerant/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/belligerant/subscriptions',
#      'organizations_url': 'https://api.github.com/users/belligerant/orgs',
#      'repos_url': 'https://api.github.com/users/belligerant/repos',
#      'events_url': 'https://api.github.com/users/belligerant/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/belligerant/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/belligerant/forty-jekyll-theme',
#     'description': 'A Jekyll version of the "Forty" theme by HTML5 UP.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme',
#     'forks_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/forks',
#     'keys_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/teams',
#     'hooks_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/hooks',
#     'issue_events_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/events',
#     'assignees_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/tags',
#     'blobs_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/languages',
#     'stargazers_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/stargazers',
#     'contributors_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/contributors',
#     'subscribers_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/subscribers',
#     'subscription_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/subscription',
#     'commits_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/merges',
#     'archive_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/downloads',
#     'issues_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/belligerant/forty-jekyll-theme/deployments',
#     'created_at': '2020-03-01T00:39:46Z',
#     'updated_at': '2020-02-27T05:14:45Z',
#     'pushed_at': '2020-02-22T19:03:38Z',
#     'git_url': 'git://github.com/belligerant/forty-jekyll-theme.git',
#     'ssh_url': 'git@github.com:belligerant/forty-jekyll-theme.git',
#     'clone_url': 'https://github.com/belligerant/forty-jekyll-theme.git',
#     'svn_url': 'https://github.com/belligerant/forty-jekyll-theme',
#     'homepage': 'https://andrewbanchich.github.io/forty-jekyll-theme/',
#     'size': 2607,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'other',
#      'name': 'Other',
#      'spdx_id': 'NOASSERTION',
#      'url': None,
#      'node_id': 'MDc6TGljZW5zZTA='},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-03-01T00:39:47Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# {'all': [{'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 10,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a090aac31001185ed16',
#    'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c489117e4f6130014c987b9',
#    'text': 'Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60982ce549020014533033',
#    'text': 'The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609852e549020014533036',
#    'text': "While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60999ae549020014533038',
#    'text': 'Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a02e549020014533039',
#    'text': "All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a90e54902001453303a',
#    'text': 'Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c35cc2d7a200140f67ea',
#    'text': 'If you really want to treat your cat, get some lactose-free milk at the grocery store and offer some to the kitty.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c47dc2d7a200140f67ee',
#    'text': 'Abraham Lincoln, being the ailurophile that he was, once rescued three stray kittens and ensured that they were fed and found homes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c4eec2d7a200140f67ef',
#    'text': 'The Sphynx was originally known as the Canadian Hairless Cat. The breed originated in Toronto, and was renamed to Sphynx, a nod to the famous limestone sculpture in the Egyptian Desert.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c6a104fc2d7a200140f699f',
#    'text': 'A cat’s spine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72d9b651021f001415f00c',
#    'text': 'Cats have been domesticated for around 4,000 years. While they were once valued for their hunting abilities, they are now valued for their companionship and loving behavior.',
#    'type': 'cat',
#    'user': {'_id': '5c6fd96df4256a001498a73f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72dbd851021f001415f010',
#    'text': 'The most popular pedigreed cat in North America is the Persian cat, followed by the Main Coon and the Siamese cat.',
#    'type': 'cat',
#    'user': {'_id': '5c72dbb751021f001415f00f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'type': 'cat',
#    'text': 'About one in two cats respond to catnip, and only develop a sensitivity to it at around 3 to 6 months of age.',
# ...
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609945e549020014533037',
#    'text': 'Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e239999dc76630015d4c5e2',
#    'type': 'cat',
#    'text': 'Cats see only on blue and yellow.',
#    'user': {'_id': '5e239963dc76630015d4c5e1',
#     'name': {'first': 'Eduardo', 'last': 'P. Gomez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e27232ec71d0900152d8518',
#    'type': 'cat',
#    'text': 'Cats are dumb.',
#    'user': {'_id': '5e272323c71d0900152d8517',
#     'name': {'first': 'Andrew', 'last': 'Steele'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e2f9f1ade397c00152dd552',
#    'type': 'cat',
#    'text': 'Cat.',
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e2f9f23de397c00152dd553',
#    'type': 'cat',
#    'text': 'Sleep.',
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e3382ccd7ac48001509e153',
#    'type': 'cat',
#    'text': 'Cat is an animal.',
#    'user': {'_id': '5e3381f3d7ac48001509e151',
#     'name': {'first': 'Dicka', 'last': 'Ismaji'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e344e7acd8efb0015ae3055',
#    'type': 'cat',
#    'text': 'Cat live, on average, for about 7-8 years.',
#    'user': {'_id': '5e344e3ccd8efb0015ae3054',
#     'name': {'first': 'RYAN', 'last': 'STULTZ'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e3534d8cd8efb0015ae305c',
#    'type': 'cat',
#    'text': 'Hi.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e35436d11559000151bf453',
#    'type': 'cat',
#    'text': '123.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e355bf411559000151bf454',
#    'type': 'cat',
#    'text': 'Fgf.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e380ea32035630015618254',
#    'type': 'cat',
#    'text': 'Asd.',
#    'user': {'_id': '5e380e9b2035630015618253',
#     'name': {'first': 'dm', 'last': 'max'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e56fdf375991a0015429ffc',
#    'type': 'cat',
#    'text': 'Bbb.',
#    'user': {'_id': '5e56fddd75991a0015429ffb',
#     'name': {'first': 'Cristian', 'last': 'Salcedo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e353507cd8efb0015ae305d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e4c4e10a38ae60015b04a7e',
#    'type': 'cat',
#    'text': "Cats think humans have night vision too, so when we step on their tail in the middle of the night, they think it's on purpose.",
#    'user': {'_id': '5e4c4dc5a38ae60015b04a7d',
#     'name': {'first': 'Nathaniel J', 'last': 'McDermott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e546a054e83e80015a0e320',
#    'type': 'cat',
#    'text': "Contrary to popular belief, some cats actually don't mind water. The hairless Sphynx cat enjoys it, especially if it is warm.",
#    'user': {'_id': '5e54675a4e83e80015a0e313',
#     'name': {'first': "L'hibou", 'last': 'Ambigu'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}
